# %% [markdown]
# ### Folder Structure
#   - GoogleDriveFolder
#     - setup_colab.ipynb   (`This is the shared setup file`)
#     - model.ipynb
#     - data/
#       - img/
#       - driving_log.csv
#     - models/
#
# ### Step 1:
#   -  Modify Google Drvie path to your project path
#   - Set up Google Drive Access
#     - `NOTE: This has to be done everyday (Limitation by colab)`
#   - Mount google drive folder to google virtual drive
#     -  `NOTE: This has to be done everyday (Limitation by colab)`
#   - Check if above config is correct
#
# ### Step 2:
#   - Install required python modules
#   - Copy google drive files to Colab disk
#     - `NOTE: This will boost data fetch process since its mounted to Colab disk`

# %%
# Step1: set up you Google Drive path
requirements_file_path = 'drive/Formula/requirements.txt'
drive_path = "drive/Formula"
drive_data_path = "drive/Formula/data"
# !python -V

# Step2: Set up Google Drive access
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}

# Mount Google Drive folder
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# Step3: Check GDrive folder status
# !ls -al $drive_path

# %%
# Step4: Install python modules and copy files to Lab
# !pip install -r $requirements_file_path
# !cp -r $drive_data_path .
# !ls $drive_data_path
